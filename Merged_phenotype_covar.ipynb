# %%
import pandas as pd

# %%
Data_directory = r'C:\Users\Admin\Documents\MiCM SUMMER SCHOLARS\Chronic_pain\DATA'

# %%
Phenotype_table = Data_directory + '\CLSA_table.tsv'

# %%
Phenotype_table_df = pd.read_csv(Phenotype_table, sep = '\t')

# %%
Phenotype_table_df
# Out:
#        Unnamed: 0       ID  BP1M_COM  BP12M_COM  BPduration_COM  location_COM  \
# 0               1  1001041       2.0        NaN             NaN           NaN
# 1               2  1001103       2.0        NaN             NaN           NaN
# 2               3  1001792       1.0        2.0             1.0           3.0
# 3               4  1001794       1.0        1.0             1.0           2.0
# 4               5  1001846       2.0        NaN             NaN           NaN
# ...           ...      ...       ...        ...             ...           ...
# 30092       30093  9997832       1.0        2.0             0.0           3.0
# 30093       30094  9998252       2.0        NaN             NaN           NaN
# 30094       30095  9998465       2.0        NaN             NaN           NaN
# 30095       30096  9999316       2.0        NaN             NaN           NaN
# 30096       30097  9999378       1.0        1.0             1.0           3.0
#
# ...

# %%
Covariates_table = Data_directory + '\CLSA_EUR_3_PCs.txt'

# %%
Covariates_table_df = pd.read_csv(Covariates_table, sep='\t')

# %%
Covariates_table_df
# Out:
#        pheno_id  geno_id  White  Norm_stats       PC1           PC2       PC3  \
# 0       6304084        1      1    1.690749  0.001808  2.554100e-07  0.000229
# 1       8718343        2      1    1.397939  0.001857  3.260340e-04 -0.000073
# 2       2212403        3      1    3.300867  0.002198 -1.281980e-04 -0.000027
# 3       4220460        4      1    1.082126  0.001758  1.182010e-04 -0.000186
# 4       8916381        5      1    4.992269  0.002115 -1.666500e-05  0.000897
# ...         ...      ...    ...         ...       ...           ...       ...
# 26617   6341509    26618      1    1.085164  0.001471 -3.339050e-04 -0.000190
# 26618   3123031    26619      1    1.265291  0.001711 -6.857750e-05  0.000017
# 26619   4962402    26620      1    1.689010  0.001849  3.059930e-04  0.000643
# 26620   5120927    26621      1    1.651589  0.001902 -6.717270e-05 -0.000311
# 26621   6100899    26622      1    4.676353  0.001701 -3.824340e-05  0.001189
#
# ...

# %%
Phenotype_table_df.drop(Phenotype_table_df.columns.difference(['ID','age_COM','sex_COM','ANY_C_BP']), axis=1, inplace=True)

# %%
Phenotype_table_df
# Out:
#             ID  age_COM sex_COM  ANY_C_BP
# 0      1001041       65       F       NaN
# 1      1001103       69       M       NaN
# 2      1001792       57       M       2.0
# 3      1001794       76       F       2.0
# 4      1001846       62       F       NaN
# ...        ...      ...     ...       ...
# 30092  9997832       67       M       2.0
# 30093  9998252       65       M       NaN
# 30094  9998465       51       M       NaN
# 30095  9999316       45       F       NaN
# 30096  9999378       65       F       2.0
#
# [30097 rows x 4 columns]

# %%
Covariates_table_df.rename(columns={'pheno_id':'ID'})
# Out:
#             ID  geno_id  White  Norm_stats       PC1           PC2       PC3  \
# 0      6304084        1      1    1.690749  0.001808  2.554100e-07  0.000229
# 1      8718343        2      1    1.397939  0.001857  3.260340e-04 -0.000073
# 2      2212403        3      1    3.300867  0.002198 -1.281980e-04 -0.000027
# 3      4220460        4      1    1.082126  0.001758  1.182010e-04 -0.000186
# 4      8916381        5      1    4.992269  0.002115 -1.666500e-05  0.000897
# ...        ...      ...    ...         ...       ...           ...       ...
# 26617  6341509    26618      1    1.085164  0.001471 -3.339050e-04 -0.000190
# 26618  3123031    26619      1    1.265291  0.001711 -6.857750e-05  0.000017
# 26619  4962402    26620      1    1.689010  0.001849  3.059930e-04  0.000643
# 26620  5120927    26621      1    1.651589  0.001902 -6.717270e-05 -0.000311
# 26621  6100899    26622      1    4.676353  0.001701 -3.824340e-05  0.001189
#
# ...

# %%
Covariates_table_df.drop(['geno_id','White','Norm_stats'],axis=1,inplace=True)

# %%
Covariates_table_df
# Out:
#        pheno_id       PC1           PC2       PC3       PC4       PC5  \
# 0       6304084  0.001808  2.554100e-07  0.000229  0.003129  0.002762
# 1       8718343  0.001857  3.260340e-04 -0.000073  0.001566  0.000504
# 2       2212403  0.002198 -1.281980e-04 -0.000027  0.004005  0.004125
# 3       4220460  0.001758  1.182010e-04 -0.000186  0.001787  0.003172
# 4       8916381  0.002115 -1.666500e-05  0.000897  0.003001  0.002664
# ...         ...       ...           ...       ...       ...       ...
# 26617   6341509  0.001471 -3.339050e-04 -0.000190  0.002797  0.005123
# 26618   3123031  0.001711 -6.857750e-05  0.000017  0.002437  0.003705
# 26619   4962402  0.001849  3.059930e-04  0.000643  0.000221  0.001505
# 26620   5120927  0.001902 -6.717270e-05 -0.000311  0.003143  0.003491
# 26621   6100899  0.001701 -3.824340e-05  0.001189  0.001163  0.001193
#
#             PC6       PC7       PC8       PC9  ...      PC41      PC42  \
# ...

# %%
Covariates_table_df.rename(columns={'pheno_id':'ID'},inplace=True)

# %%
Covariates_table_df
# Out:
#             ID       PC1           PC2       PC3       PC4       PC5  \
# 0      6304084  0.001808  2.554100e-07  0.000229  0.003129  0.002762
# 1      8718343  0.001857  3.260340e-04 -0.000073  0.001566  0.000504
# 2      2212403  0.002198 -1.281980e-04 -0.000027  0.004005  0.004125
# 3      4220460  0.001758  1.182010e-04 -0.000186  0.001787  0.003172
# 4      8916381  0.002115 -1.666500e-05  0.000897  0.003001  0.002664
# ...        ...       ...           ...       ...       ...       ...
# 26617  6341509  0.001471 -3.339050e-04 -0.000190  0.002797  0.005123
# 26618  3123031  0.001711 -6.857750e-05  0.000017  0.002437  0.003705
# 26619  4962402  0.001849  3.059930e-04  0.000643  0.000221  0.001505
# 26620  5120927  0.001902 -6.717270e-05 -0.000311  0.003143  0.003491
# 26621  6100899  0.001701 -3.824340e-05  0.001189  0.001163  0.001193
#
#             PC6       PC7       PC8       PC9  ...      PC41      PC42  \
# ...

# %%
Pheno_covar_merged_table = pd.merge(Phenotype_table_df,Covariates_table_df,on='ID',how='inner')

# %%
Pheno_covar_merged_table
# Out:
#             ID  age_COM sex_COM  ANY_C_BP       PC1       PC2       PC3  \
# 0      1001041       65       F       NaN  0.001344  0.000544  0.001706
# 1      1001103       69       M       NaN  0.001307 -0.000131  0.000323
# 2      1001792       57       M       2.0  0.001600 -0.000108  0.000903
# 3      1001794       76       F       2.0  0.001902 -0.000055  0.000088
# 4      1001846       62       F       NaN -0.024413 -0.022108  0.008200
# ...        ...      ...     ...       ...       ...       ...       ...
# 26617  9997119       75       F       2.0  0.001984 -0.000068  0.000408
# 26618  9997832       67       M       2.0  0.001825 -0.000030 -0.000295
# 26619  9998252       65       M       NaN  0.001499  0.000781  0.000787
# 26620  9998465       51       M       NaN  0.001874  0.000313  0.000797
# 26621  9999316       45       F       NaN  0.001507  0.000160 -0.000817
#
#             PC4       PC5       PC6  ...      PC41      PC42      PC43  \
# ...

# %%
Pheno_covar_merged_table.to_csv(r'C:\Users\Admin\Documents\MiCM SUMMER SCHOLARS\Chronic_pain\DATA\Pheno_covar_CLSA_EUR.tsv', sep='\t',index = False)

# %%
Pheno_to_geno_id_key_table = Data_directory + '\pheno_to_geno_id_key.tsv'

# %%
Pheno_to_geno_id_key_table_df = pd.read_csv(Pheno_to_geno_id_key_table, sep='\t')

# %%
Pheno_to_geno_id_key_table_df
# Out:
#        pheno_id  geno_id
# 0       4500312     9023
# 1       5380061     3765
# 2       3355167    17454
# 3       9996139     8210
# 4       1642249    10701
# ...         ...      ...
# 26617   8801838     3693
# 26618   4614853    21639
# 26619   1860690     7300
# 26620   4913173     5366
# 26621   8245397    15535
#
# [26622 rows x 2 columns]

# %%
Pheno_to_geno_id_key_table_df.rename(columns={'pheno_id':'ID'},inplace=True)

# %%
Pheno_geno_covar_df = pd.merge(Pheno_to_geno_id_key_table_df,Pheno_covar_merged_table,how='inner',on='ID')

# %%
Pheno_to_geno_id_key_table_df
# Out:
#             ID  geno_id
# 0      4500312     9023
# 1      5380061     3765
# 2      3355167    17454
# 3      9996139     8210
# 4      1642249    10701
# ...        ...      ...
# 26617  8801838     3693
# 26618  4614853    21639
# 26619  1860690     7300
# 26620  4913173     5366
# 26621  8245397    15535
#
# [26622 rows x 2 columns]

# %%
Pheno_geno_covar_df
# Out:
#             ID  geno_id  age_COM sex_COM  ANY_C_BP       PC1       PC2  \
# 0      4500312     9023       76       M       NaN -0.006577 -0.002937
# 1      5380061     3765       76       F       2.0  0.001844 -0.000371
# 2      3355167    17454       64       F       1.0  0.001720  0.000115
# 3      9996139     8210       57       M       NaN -0.000691  0.001307
# 4      1642249    10701       50       M       NaN  0.001533  0.000518
# ...        ...      ...      ...     ...       ...       ...       ...
# 26617  8801838     3693       64       F       NaN  0.001939 -0.000003
# 26618  4614853    21639       60       M       NaN  0.001950  0.000240
# 26619  1860690     7300       68       M       NaN  0.001782  0.000022
# 26620  4913173     5366       53       M       NaN  0.001790 -0.000191
# 26621  8245397    15535       77       F       NaN  0.001658 -0.000118
#
#             PC3       PC4       PC5  ...      PC41      PC42      PC43  \
# ...

# %%
Pheno_geno_covar_df.rename(columns={'ID':'pheno_id'},inplace=True)

# %%
Pheno_geno_covar_df
# Out:
#        pheno_id  geno_id  age_COM sex_COM  ANY_C_BP       PC1       PC2  \
# 0       4500312     9023       76       M       NaN -0.006577 -0.002937
# 1       5380061     3765       76       F       2.0  0.001844 -0.000371
# 2       3355167    17454       64       F       1.0  0.001720  0.000115
# 3       9996139     8210       57       M       NaN -0.000691  0.001307
# 4       1642249    10701       50       M       NaN  0.001533  0.000518
# ...         ...      ...      ...     ...       ...       ...       ...
# 26617   8801838     3693       64       F       NaN  0.001939 -0.000003
# 26618   4614853    21639       60       M       NaN  0.001950  0.000240
# 26619   1860690     7300       68       M       NaN  0.001782  0.000022
# 26620   4913173     5366       53       M       NaN  0.001790 -0.000191
# 26621   8245397    15535       77       F       NaN  0.001658 -0.000118
#
#             PC3       PC4       PC5  ...      PC41      PC42      PC43  \
# ...

# %%
Pheno_geno_covar_df.rename(columns={'geno_id':'ID'},inplace=True)

# %%
Pheno_geno_covar_df
# Out:
#        pheno_id     ID  age_COM sex_COM  ANY_C_BP       PC1       PC2  \
# 0       4500312   9023       76       M       NaN -0.006577 -0.002937
# 1       5380061   3765       76       F       2.0  0.001844 -0.000371
# 2       3355167  17454       64       F       1.0  0.001720  0.000115
# 3       9996139   8210       57       M       NaN -0.000691  0.001307
# 4       1642249  10701       50       M       NaN  0.001533  0.000518
# ...         ...    ...      ...     ...       ...       ...       ...
# 26617   8801838   3693       64       F       NaN  0.001939 -0.000003
# 26618   4614853  21639       60       M       NaN  0.001950  0.000240
# 26619   1860690   7300       68       M       NaN  0.001782  0.000022
# 26620   4913173   5366       53       M       NaN  0.001790 -0.000191
# 26621   8245397  15535       77       F       NaN  0.001658 -0.000118
#
#             PC3       PC4       PC5  ...      PC41      PC42      PC43  \
# ...

# %%
Pheno_geno_covar_df.to_csv(r'C:\Users\Admin\Documents\MiCM SUMMER SCHOLARS\Chronic_pain\DATA\Pheno_geno_covar.tsv', sep='\t',index = False)

# %%
Pheno_geno_covar_df
# Out:
#        pheno_id     ID  age_COM sex_COM  ANY_C_BP       PC1       PC2  \
# 0       4500312   9023       76       M       NaN -0.006577 -0.002937
# 1       5380061   3765       76       F       2.0  0.001844 -0.000371
# 2       3355167  17454       64       F       1.0  0.001720  0.000115
# 3       9996139   8210       57       M       NaN -0.000691  0.001307
# 4       1642249  10701       50       M       NaN  0.001533  0.000518
# ...         ...    ...      ...     ...       ...       ...       ...
# 26617   8801838   3693       64       F       NaN  0.001939 -0.000003
# 26618   4614853  21639       60       M       NaN  0.001950  0.000240
# 26619   1860690   7300       68       M       NaN  0.001782  0.000022
# 26620   4913173   5366       53       M       NaN  0.001790 -0.000191
# 26621   8245397  15535       77       F       NaN  0.001658 -0.000118
#
#             PC3       PC4       PC5  ...      PC41      PC42      PC43  \
# ...

# %%
Pheno_covar_non_NA_df = Pheno_covar_merged_table.loc[Pheno_covar_merged_table['ANY_C_BP'].notnull(), ['ID','ANY_C_BP','age_COM','sex_COM','PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12','PC13','PC14','PC15','PC16','PC17','PC18','PC19','PC20','PC21','PC22','PC23','PC24','PC25','PC26','PC27','PC28','PC29','PC30','PC31','PC32','PC33','PC34','PC35','PC36','PC37','PC38','PC39','PC40','PC41','PC42','PC43','PC44','PC45','PC46','PC47','PC48','PC49','PC50']]

# %%
Pheno_covar_non_NA_df
# Out:
#             ID  ANY_C_BP  age_COM sex_COM       PC1       PC2       PC3  \
# 2      1001792       2.0       57       M  0.001600 -0.000108  0.000903
# 3      1001794       2.0       76       F  0.001902 -0.000055  0.000088
# 8      1003313       2.0       64       M -0.005860 -0.002510 -0.001875
# 14     1005568       2.0       50       F  0.001948  0.000051  0.000682
# 16     1005926       2.0       76       F  0.001820  0.000068  0.001101
# ...        ...       ...      ...     ...       ...       ...       ...
# 26606  9990679       2.0       45       M  0.001642  0.000378  0.000887
# 26609  9993777       2.0       54       F  0.001606  0.000244 -0.000548
# 26612  9994799       2.0       47       F -0.011164 -0.005440  0.001329
# 26617  9997119       2.0       75       F  0.001984 -0.000068  0.000408
# 26618  9997832       2.0       67       M  0.001825 -0.000030 -0.000295
#
#             PC4       PC5       PC6  ...      PC41      PC42      PC43  \
# ...

# %%
Pheno_covar_non_NA_df.to_csv(r'C:\Users\Admin\Documents\MiCM SUMMER SCHOLARS\Chronic_pain\DATA\Pheno_covar_non_NA.tsv', sep='\t',index = False)

# %%
New_geno_pheno = Data_directory + '\\test.tsv'

# %%
New_geno_pheno_df = pd.read_csv(New_geno_pheno, sep = '\t')

# %%
New_geno_pheno_df
# Out:
#        Unnamed: 0     ID  BP1M_COM  BP12M_COM  BPduration_COM  location_COM  \
# 0               1   9023       2.0        NaN             NaN           NaN
# 1               2   3765       1.0        2.0             1.0           3.0
# 2               3  17454       1.0        1.0             0.0           3.0
# 3               4   8210       2.0        NaN             NaN           NaN
# 4               5  10701       2.0        NaN             NaN           NaN
# ...           ...    ...       ...        ...             ...           ...
# 26617       26618   3693       2.0        NaN             NaN           NaN
# 26618       26619  21639       2.0        NaN             NaN           NaN
# 26619       26620   7300       2.0        NaN             NaN           NaN
# 26620       26621   5366       2.0        NaN             NaN           NaN
# 26621       26622  15535       2.0        NaN             NaN           NaN
#
# ...

# %%
New_CLSA_table = Data_directory + '\\CLSA_table_new.tsv'

# %%
New_CLSA_table_df = New_CLSA_table_df = pd.read_csv(New_CLSA_table, sep = '\t')

# %%
New_CLSA_table_df
# Out:
#        Unnamed: 0       ID  BP1M_COM  BP12M_COM  BPduration_COM  location_COM  \
# 0               1  1001041       2.0        NaN             NaN           NaN
# 1               2  1001103       2.0        NaN             NaN           NaN
# 2               3  1001792       1.0        2.0             1.0           3.0
# 3               4  1001794       1.0        1.0             1.0           2.0
# 4               5  1001846       2.0        NaN             NaN           NaN
# ...           ...      ...       ...        ...             ...           ...
# 30092       30093  9997832       1.0        2.0             0.0           3.0
# 30093       30094  9998252       2.0        NaN             NaN           NaN
# 30094       30095  9998465       2.0        NaN             NaN           NaN
# 30095       30096  9999316       2.0        NaN             NaN           NaN
# 30096       30097  9999378       1.0        1.0             1.0           3.0
#
# ...

# %%
New_merged_CLSA_table = pd.merge(New_CLSA_table_df,Covariates_table_df,on='ID',how='inner')

# %%
New_merged_CLSA_table
# Out:
#        Unnamed: 0       ID  BP1M_COM  BP12M_COM  BPduration_COM  location_COM  \
# 0               1  1001041       2.0        NaN             NaN           NaN
# 1               2  1001103       2.0        NaN             NaN           NaN
# 2               3  1001792       1.0        2.0             1.0           3.0
# 3               4  1001794       1.0        1.0             1.0           2.0
# 4               5  1001846       2.0        NaN             NaN           NaN
# ...           ...      ...       ...        ...             ...           ...
# 26617       30091  9997119       1.0        2.0             1.0           3.0
# 26618       30093  9997832       1.0        2.0             0.0           3.0
# 26619       30094  9998252       2.0        NaN             NaN           NaN
# 26620       30095  9998465       2.0        NaN             NaN           NaN
# 26621       30096  9999316       2.0        NaN             NaN           NaN
#
# ...

# %%
New_pheno_geno_covar_df = pd.merge(Pheno_to_geno_id_key_table_df,New_merged_CLSA_table,how='inner',on='ID')

# %%
New_pheno_geno_covar_df
# Out:
#             ID  geno_id  Unnamed: 0  BP1M_COM  BP12M_COM  BPduration_COM  \
# 0      4500312     9023       11827       2.0        NaN             NaN
# 1      5380061     3765       14812       1.0        2.0             1.0
# 2      3355167    17454        7921       1.0        1.0             0.0
# 3      9996139     8210       30089       2.0        NaN             NaN
# 4      1642249    10701        2112       2.0        NaN             NaN
# ...        ...      ...         ...       ...        ...             ...
# 26617  8801838     3693       26170       2.0        NaN             NaN
# 26618  4614853    21639       12230       2.0        NaN             NaN
# 26619  1860690     7300        2903       2.0        NaN             NaN
# 26620  4913173     5366       13225       2.0        NaN             NaN
# 26621  8245397    15535       24303       2.0        NaN             NaN
#
#        location_COM  pain_free_COM  intensity_COM  Bpproblem_COM  ...  \
# ...

# %%
New_pheno_geno_covar_df.rename(columns={'ID':'pheno_id'},inplace=True)

# %%
New_pheno_geno_covar_df.rename(columns={'geno_id':'ID'},inplace=True)

# %%
New_pheno_geno_covar_df
# Out:
#        pheno_id     ID  Unnamed: 0  BP1M_COM  BP12M_COM  BPduration_COM  \
# 0       4500312   9023       11827       2.0        NaN             NaN
# 1       5380061   3765       14812       1.0        2.0             1.0
# 2       3355167  17454        7921       1.0        1.0             0.0
# 3       9996139   8210       30089       2.0        NaN             NaN
# 4       1642249  10701        2112       2.0        NaN             NaN
# ...         ...    ...         ...       ...        ...             ...
# 26617   8801838   3693       26170       2.0        NaN             NaN
# 26618   4614853  21639       12230       2.0        NaN             NaN
# 26619   1860690   7300        2903       2.0        NaN             NaN
# 26620   4913173   5366       13225       2.0        NaN             NaN
# 26621   8245397  15535       24303       2.0        NaN             NaN
#
#        location_COM  pain_free_COM  intensity_COM  Bpproblem_COM  ...  \
# ...

# %%
New_pheno_geno_covar_df.to_csv(r'C:\Users\Admin\Documents\MiCM SUMMER SCHOLARS\Chronic_pain\DATA\New_merged_pheno_covar_table.tsv', sep='\t',index = False)

# %%
Updated_CLSA_table = Data_directory + '\\CLSA_table_new_new.tsv'

# %%
Updated_CLSA_table_df = pd.read_csv(Updated_CLSA_table, sep = '\t')

# %%
Updated_CLSA_table_df
# Out:
#        Unnamed: 0       ID  BP1M_COM  BP12M_COM  BPduration_COM  location_COM  \
# 0               1  1001041       2.0        NaN             NaN           NaN
# 1               2  1001103       2.0        NaN             NaN           NaN
# 2               3  1001792       1.0        2.0             1.0           3.0
# 3               4  1001794       1.0        1.0             1.0           2.0
# 4               5  1001846       2.0        NaN             NaN           NaN
# ...           ...      ...       ...        ...             ...           ...
# 30092       30093  9997832       1.0        2.0             0.0           3.0
# 30093       30094  9998252       2.0        NaN             NaN           NaN
# 30094       30095  9998465       2.0        NaN             NaN           NaN
# 30095       30096  9999316       2.0        NaN             NaN           NaN
# 30096       30097  9999378       1.0        1.0             1.0           3.0
#
# ...

# %%
Updated_CLSA_table = pd.merge(Updated_CLSA_table_df,Covariates_table_df,on='ID',how='inner')

# %%
Updated_CLSA_table
# Out:
#        Unnamed: 0       ID  BP1M_COM  BP12M_COM  BPduration_COM  location_COM  \
# 0               1  1001041       2.0        NaN             NaN           NaN
# 1               2  1001103       2.0        NaN             NaN           NaN
# 2               3  1001792       1.0        2.0             1.0           3.0
# 3               4  1001794       1.0        1.0             1.0           2.0
# 4               5  1001846       2.0        NaN             NaN           NaN
# ...           ...      ...       ...        ...             ...           ...
# 26617       30091  9997119       1.0        2.0             1.0           3.0
# 26618       30093  9997832       1.0        2.0             0.0           3.0
# 26619       30094  9998252       2.0        NaN             NaN           NaN
# 26620       30095  9998465       2.0        NaN             NaN           NaN
# 26621       30096  9999316       2.0        NaN             NaN           NaN
#
# ...

# %%
Updated_pheno_geno_covar_df = pd.merge(Pheno_to_geno_id_key_table_df,Updated_CLSA_table,how='inner',on='ID')

# %%
Updated_pheno_geno_covar_df
# Out:
#             ID  geno_id  Unnamed: 0  BP1M_COM  BP12M_COM  BPduration_COM  \
# 0      4500312     9023       11827       2.0        NaN             NaN
# 1      5380061     3765       14812       1.0        2.0             1.0
# 2      3355167    17454        7921       1.0        1.0             0.0
# 3      9996139     8210       30089       2.0        NaN             NaN
# 4      1642249    10701        2112       2.0        NaN             NaN
# ...        ...      ...         ...       ...        ...             ...
# 26617  8801838     3693       26170       2.0        NaN             NaN
# 26618  4614853    21639       12230       2.0        NaN             NaN
# 26619  1860690     7300        2903       2.0        NaN             NaN
# 26620  4913173     5366       13225       2.0        NaN             NaN
# 26621  8245397    15535       24303       2.0        NaN             NaN
#
#        location_COM  pain_free_COM  intensity_COM  Bpproblem_COM  ...  \
# ...

# %%
Updated_pheno_geno_covar_df.rename(columns={'ID':'pheno_id'},inplace=True)

# %%
Updated_pheno_geno_covar_df.rename(columns={'geno_id':'ID'},inplace=True)

# %%
Updated_pheno_geno_covar_df
# Out:
#        pheno_id     ID  Unnamed: 0  BP1M_COM  BP12M_COM  BPduration_COM  \
# 0       4500312   9023       11827       2.0        NaN             NaN
# 1       5380061   3765       14812       1.0        2.0             1.0
# 2       3355167  17454        7921       1.0        1.0             0.0
# 3       9996139   8210       30089       2.0        NaN             NaN
# 4       1642249  10701        2112       2.0        NaN             NaN
# ...         ...    ...         ...       ...        ...             ...
# 26617   8801838   3693       26170       2.0        NaN             NaN
# 26618   4614853  21639       12230       2.0        NaN             NaN
# 26619   1860690   7300        2903       2.0        NaN             NaN
# 26620   4913173   5366       13225       2.0        NaN             NaN
# 26621   8245397  15535       24303       2.0        NaN             NaN
#
#        location_COM  pain_free_COM  intensity_COM  Bpproblem_COM  ...  \
# ...

# %%
Updated_pheno_geno_covar_df.to_csv(r'C:\Users\Admin\Documents\MiCM SUMMER SCHOLARS\Chronic_pain\DATA\Updated_pheno_covar_table.tsv', sep='\t',index = False)

# %%
Updated_pheno_geno_covar_df.dtypes
# Out:
# pheno_id        int64
# ID              int64
# Unnamed: 0      int64
# BP1M_COM      float64
# BP12M_COM     float64
#                ...
# PC46          float64
# PC47          float64
# PC48          float64
# PC49          float64
# PC50          float64
# Length: 82, dtype: object

# %%
conda install -c conda-forge pandas-plink
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
pip install pandas-plink
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas_plink import read_plink

# %%
(bim,fam,bed) = read_plink(r'C:\Users\Admin\Documents\MiCM SUMMER SCHOLARS\Chronic_pain\DATA\CLSA_EUR', verbose=False)

# %%
print(bim.head())
# Out:
#   chrom          snp      cm     pos a0 a1  i
# 0     1  AX-37361813  0.0080  727841  A  G  0
# 1     1  AX-32137419  0.0081  729632  T  C  1
# 2     1  AX-13191280  0.0083  752721  A  G  2
# 3     1  AX-11194291  0.0083  754105  T  C  3
# 4     1  AX-32225497  0.0084  756604  A  G  4

# %%
print(bim.dtypes)
# Out:
# chrom    category
# snp        object
# cm        float64
# pos         int64
# a0       category
# a1       category
# i           int32
# dtype: object

# %%
bim
# Out:
#        chrom          snp      cm     pos a0 a1       i
# 0          1  AX-37361813  0.0080  727841  A  G       0
# 1          1  AX-32137419  0.0081  729632  T  C       1
# 2          1  AX-13191280  0.0083  752721  A  G       2
# 3          1  AX-11194291  0.0083  754105  T  C       3
# 4          1  AX-32225497  0.0084  756604  A  G       4
# ...      ...          ...     ...     ... .. ..     ...
# 794404    MT  AX-94381009  0.0000   16270  T  C  794404
# 794405    MT  AX-94364268  0.0000   16337  .  C  794405
# 794406    MT  AX-90053957  0.0000   16356  C  T  794406
# 794407    MT  AX-90082843  0.0000   16362  C  T  794407
# 794408    MT  AX-94381010  0.0000   16391  A  G  794408
#
# [794409 rows x 7 columns]

# %%
bim_new = bim[bim.chrom.apply(lambda x: x.isnumeric())]

# %%
bim_new
# Out:
#        chrom          snp      cm       pos a0 a1       i
# 0          1  AX-37361813  0.0080    727841  A  G       0
# 1          1  AX-32137419  0.0081    729632  T  C       1
# 2          1  AX-13191280  0.0083    752721  A  G       2
# 3          1  AX-11194291  0.0083    754105  T  C       3
# 4          1  AX-32225497  0.0084    756604  A  G       4
# ...      ...          ...     ...       ... .. ..     ...
# 773475    22  AX-83120930  0.7561  51183255  A  G  773475
# 773476    22  AX-33748977  0.7562  51185848  G  A  773476
# 773477    22  AX-13913362  0.7565  51193629  G  A  773477
# 773478    22  AX-33749029  0.7574  51217954  A  G  773478
# 773479    22  AX-38030843  0.7576  51224208  A  G  773479
#
# [773480 rows x 7 columns]

# %%
print(bim_new.dtypes)
# Out:
# chrom    category
# snp        object
# cm        float64
# pos         int64
# a0       category
# a1       category
# i           int32
# dtype: object

# %%
Final_CLSA_table = Data_directory + '\CLSA_table_1.tsv'

# %%
Final_CLSA_table_df = pd.read_csv(Final_CLSA_table,sep='\t')

# %%
Final_CLSA_table_df
# Out:
#        Unnamed: 0       ID  BP1M_COM  BP12M_COM  BPduration_COM  location_COM  \
# 0               1  1001041       2.0        NaN             NaN           NaN
# 1               2  1001103       2.0        NaN             NaN           NaN
# 2               3  1001792       1.0        2.0             1.0           3.0
# 3               4  1001794       1.0        1.0             1.0           2.0
# 4               5  1001846       2.0        NaN             NaN           NaN
# ...           ...      ...       ...        ...             ...           ...
# 30092       30093  9997832       1.0        2.0             0.0           3.0
# 30093       30094  9998252       2.0        NaN             NaN           NaN
# 30094       30095  9998465       2.0        NaN             NaN           NaN
# 30095       30096  9999316       2.0        NaN             NaN           NaN
# 30096       30097  9999378       1.0        1.0             1.0           3.0
#
# ...

# %%
Merged_pheno_table_df = pd.merge(Final_CLSA_table_df,Covariates_table_df,on='ID',how='inner')

# %%
Merged_pheno_table_df
# Out:
#        pheno_id     ID  Unnamed: 0  BP1M_COM  BP12M_COM  BPduration_COM  \
# 0       4500312   9023       11827       2.0        NaN             NaN
# 1       5380061   3765       14812       1.0        2.0             1.0
# 2       3355167  17454        7921       1.0        1.0             0.0
# 3       9996139   8210       30089       2.0        NaN             NaN
# 4       1642249  10701        2112       2.0        NaN             NaN
# ...         ...    ...         ...       ...        ...             ...
# 26617   8801838   3693       26170       2.0        NaN             NaN
# 26618   4614853  21639       12230       2.0        NaN             NaN
# 26619   1860690   7300        2903       2.0        NaN             NaN
# 26620   4913173   5366       13225       2.0        NaN             NaN
# 26621   8245397  15535       24303       2.0        NaN             NaN
#
#        location_COM  pain_free_COM  intensity_COM  Bpproblem_COM  ...  \
# ...

# %%
Merged_pheno_table_df = pd.merge(Pheno_to_geno_id_key_table_df,Merged_pheno_table_df,how='inner',on='ID')

# %%
Merged_pheno_table_df
# Out:
#             ID  geno_id  Unnamed: 0  BP1M_COM  BP12M_COM  BPduration_COM  \
# 0      4500312     9023       11827       2.0        NaN             NaN
# 1      5380061     3765       14812       1.0        2.0             1.0
# 2      3355167    17454        7921       1.0        1.0             0.0
# 3      9996139     8210       30089       2.0        NaN             NaN
# 4      1642249    10701        2112       2.0        NaN             NaN
# ...        ...      ...         ...       ...        ...             ...
# 26617  8801838     3693       26170       2.0        NaN             NaN
# 26618  4614853    21639       12230       2.0        NaN             NaN
# 26619  1860690     7300        2903       2.0        NaN             NaN
# 26620  4913173     5366       13225       2.0        NaN             NaN
# 26621  8245397    15535       24303       2.0        NaN             NaN
#
#        location_COM  pain_free_COM  intensity_COM  Bpproblem_COM  ...  \
# ...

# %%
Merged_pheno_table_df.rename(columns={'ID':'pheno_id'},inplace=True)

# %%
Merged_pheno_table_df.rename(columns={'geno_id':'ID'},inplace=True)

# %%
Merged_pheno_table_df
# Out:
#        pheno_id     ID  Unnamed: 0  BP1M_COM  BP12M_COM  BPduration_COM  \
# 0       4500312   9023       11827       2.0        NaN             NaN
# 1       5380061   3765       14812       1.0        2.0             1.0
# 2       3355167  17454        7921       1.0        1.0             0.0
# 3       9996139   8210       30089       2.0        NaN             NaN
# 4       1642249  10701        2112       2.0        NaN             NaN
# ...         ...    ...         ...       ...        ...             ...
# 26617   8801838   3693       26170       2.0        NaN             NaN
# 26618   4614853  21639       12230       2.0        NaN             NaN
# 26619   1860690   7300        2903       2.0        NaN             NaN
# 26620   4913173   5366       13225       2.0        NaN             NaN
# 26621   8245397  15535       24303       2.0        NaN             NaN
#
#        location_COM  pain_free_COM  intensity_COM  Bpproblem_COM  ...  \
# ...

# %%
Merged_pheno_table_df.to_csv(r'C:\Users\Admin\Documents\MiCM SUMMER SCHOLARS\Chronic_pain\DATA\Merged_pheno_covar_table.tsv', sep='\t',index = False)
